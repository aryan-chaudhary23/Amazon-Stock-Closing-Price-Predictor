# %%
import pandas as pd

# %%
dataset=pd.read_csv('AMZN.csv')

# %%
dataset.sample(5)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1024  2001-06-07   15.820000   16.230000   15.690000   16.129999   16.129999
# 90    1997-09-23    4.489583    4.645833    4.395833    4.625000    4.625000
# 1655  2003-12-12   50.990002   51.310001   49.919998   50.990002   50.990002
# 3435  2011-01-07  187.880005  188.449997  183.740005  185.490005  185.490005
# 4449  2015-01-21  289.640015  306.000000  287.260010  297.250000  297.250000
#
#         Volume
# 1024   3445200
# 90     7682400
# 1655   6190600
# 3435   5221700
# 4449  10065100

# %%
import plotly.express as px

# %%
fig = px.line(dataset,x = 'Date', y = ['High','Low'], template = 'plotly_dark')
fig.show()

# %%
import plotly.graph_objects as go #to create Candlestick Chart

# %%
dataset['Date']=pd.to_datetime(dataset['Date'])

# %%
fig = go.Figure(data=[go.Candlestick(
    x=dataset['Date'], 
    open=dataset['Open'], 
    high=dataset['High'], 
    low=dataset['Low'], 
    close=dataset['Close'],
    increasing_line_color='green', 
    decreasing_line_color='red'
)])

# %%
fig.update_layout(
    template='plotly_dark',
    title='Candlestick Chart',
    xaxis_title='Date',
    yaxis_title='Price',
    xaxis_rangeslider_visible=False
)

# %%
dataset.drop('Adj Close',axis=1,inplace=True)

# %%
dataset.head()
# Out:
#         Date      Open      High       Low     Close    Volume
# 0 1997-05-15  2.437500  2.500000  1.927083  1.958333  72156000
# 1 1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000
# 2 1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800
# 3 1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200
# 4 1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200

# %%
X=dataset.iloc[:,:]

# %%
X.drop('Close',axis=1,inplace=True)

# %%
X.drop('Date',axis=1,inplace=True)

# %%
X.head()
# Out:
#        Open      High       Low    Volume
# 0  2.437500  2.500000  1.927083  72156000
# 1  1.968750  1.979167  1.708333  14700000
# 2  1.760417  1.770833  1.625000   6106800
# 3  1.729167  1.750000  1.635417   5467200
# 4  1.635417  1.645833  1.375000  18853200

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
Y= dataset.iloc[:,4:5]

# %%
Y.head()
# Out:
#       Close
# 0  1.958333
# 1  1.729167
# 2  1.708333
# 3  1.635417
# 4  1.427083

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
Y_test.head()
# Out:
#           Close
# 15     1.656250
# 2415  39.419998
# 2961  61.709999
# 103    3.901042
# 2834  82.129997

# %%
X_test.head()
# Out:
#            Open       High        Low   Volume
# 15     1.515625   1.708333   1.510417  7807200
# 2415  38.779999  39.720001  38.230000  7520000
# 2961  64.160004  64.910004  61.520000  7336000
# 103    3.729167   4.062500   3.666667  3787200
# 2834  82.000000  83.250000  81.199997  5950600

# %%
X_train.head()
# Out:
#             Open        High         Low    Volume
# 4851  763.000000  763.409973  755.359985   1744100
# 375    20.312500   21.239582   20.125000  21843600
# 4839  766.809998  767.000000  761.020020   1986300
# 3189  126.309998  128.000000  124.330002   8892600
# 4638  572.000000  573.000000  555.280029   4346200

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet

# %%
reg=ElasticNet(alpha=0.1,l1_ratio=0.9,max_iter=100000)

# %%
regl=LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# ElasticNet(alpha=0.1, l1_ratio=0.9, max_iter=100000)

# %%
regl.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
aa=reg.predict(X_test_wo_dates)

# %%
bb=regl.predict(X_test_wo_dates)

# %%
aa
# Out:
# array([1.71770820e+00, 3.92055562e+01, 6.35320908e+01, ...,
#        2.14762264e+03, 1.22019396e+02, 7.01595942e+00])

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(Y_test,aa))
# Out:
# 0.9998861306293093

# %%
print(r2_score(Y_test,bb))
# Out:
# 0.9999219788552536

# %%
import numpy as np

# %%
X_new = pd.DataFrame({
    'Open': [194.45],
    'High': [195.59],
    'Low' : [188.80],
    'Volume' : [1806380]
})

# %%
X_new.head()
# Out:
#      Open    High    Low   Volume
# 0  194.45  195.59  188.8  1806380

# %%
print(reg.predict(X_new))
# Out:
# [192.76529296]
